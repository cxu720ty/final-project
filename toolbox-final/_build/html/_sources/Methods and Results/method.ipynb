# %% [markdown]
# ## Methods
# ![method](../method.png)

# %% [markdown]
# Since I am only interested in computing the themes with the most sets, I will need to use tables that contain information on movies total gross and disney director. This implies that I will need to use the **disney_movies_total_gross** and the **disney_director** tables.
#
# However, before moving further, let us import the tables and do some basic visualizations.

# %%
# Lets import all the required libraries needed for this analysis
import altair as alt
import pandas as pd
import numpy as np
# import all the required files
total_gross = pd.read_csv("data/disney_movies_total_gross.csv")
movie_director = pd.read_csv("data/disney-director.csv")

# %% [markdown]
# Lets see what the tables look like.

# %%
total_gross.head()
# Out:
#                        movie_title  release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                        Pinocchio   Feb 9, 1940  Adventure           G
# 2                         Fantasia  Nov 13, 1940    Musical           G
# 3                Song of the South  Nov 12, 1946  Adventure           G
# 4                       Cinderella  Feb 15, 1950      Drama           G
#
#     total_gross inflation_adjusted_gross
# 0  $184,925,485           $5,228,953,251
# 1   $84,300,000           $2,188,229,052
# 2   $83,320,000           $2,187,090,808
# 3   $65,000,000           $1,078,510,579
# 4   $85,000,000             $920,608,730

# %%
movie_director.head()
# Out:
#                               name        director
# 0  Snow White and the Seven Dwarfs      David Hand
# 1                        Pinocchio  Ben Sharpsteen
# 2                         Fantasia    full credits
# 3                            Dumbo  Ben Sharpsteen
# 4                            Bambi      David Hand

# %% [markdown]
# Lets get some other information about the sets table.

# %%
total_gross.info()
print(total_gross['total_gross'].dtype)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   MPAA_rating               523 non-null    object
#  4   total_gross               579 non-null    object
#  5   inflation_adjusted_gross  579 non-null    object
# dtypes: object(6)
# memory usage: 27.3+ KB
# object

# %% [markdown]
# The sets table has $579$ rows and $6$ columns. Every **movie_title** has a **release_Date**, a **total_gross**, the **inflation_adjusted_gross**.

# %% [markdown]
# Lets get some other information about the **movie_director** table.

# %%
movie_director.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      56 non-null     object
#  1   director  56 non-null     object
# dtypes: object(2)
# memory usage: 1.0+ KB

# %% [markdown]
# The **movie_director** table has $56$ rows with $2$ columns. Every movie name has an **director**.

# %% [markdown]
# As a first visualization, lets look at the average inflation adjusted gross in each genre. To do this, I will merge table **movie_director** with **total_gross** as **direct_gross**.

# %%
direct_gross=total_gross.merge(movie_director, left_on='movie_title', right_on='name', how='left', indicator=True)
direct_gross
# Out:
#                          movie_title  release_date      genre MPAA_rating  \
# 0    Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                          Pinocchio   Feb 9, 1940  Adventure           G
# 2                           Fantasia  Nov 13, 1940    Musical           G
# 3                  Song of the South  Nov 12, 1946  Adventure           G
# 4                         Cinderella  Feb 15, 1950      Drama           G
# ..                               ...           ...        ...         ...
# 574         The Light Between Oceans   Sep 2, 2016      Drama       PG-13
# 575                   Queen of Katwe  Sep 23, 2016      Drama          PG
# 576                   Doctor Strange   Nov 4, 2016  Adventure       PG-13
# 577                            Moana  Nov 23, 2016  Adventure          PG
# 578     Rogue One: A Star Wars Story  Dec 16, 2016  Adventure       PG-13
#
#       total_gross inflation_adjusted_gross                             name  \
# 0    $184,925,485           $5,228,953,251  Snow White and the Seven Dwarfs
# 1     $84,300,000           $2,188,229,052                        Pinocchio
# 2     $83,320,000           $2,187,090,808                         Fantasia
# 3     $65,000,000           $1,078,510,579                              NaN
# 4     $85,000,000             $920,608,730                       Cinderella
# ..            ...                      ...                              ...
# 574   $12,545,979              $12,545,979                              NaN
# 575    $8,874,389               $8,874,389                              NaN
# 576  $232,532,923             $232,532,923                              NaN
# 577  $246,082,029             $246,082,029                            Moana
# 578  $529,483,936             $529,483,936                              NaN
#
#             director     _merge
# 0         David Hand       both
# 1     Ben Sharpsteen       both
# 2       full credits       both
# 3                NaN  left_only
# 4    Wilfred Jackson       both
# ..               ...        ...
# 574              NaN  left_only
# 575              NaN  left_only
# 576              NaN  left_only
# 577     Ron Clements       both
# 578              NaN  left_only
#
# [579 rows x 9 columns]

# %% [markdown]
# After that I will use the **total_gross** table. I will group by director and then compute the average inflation adjusted gross for each director.

# %%
#get year from releasae date, and add year column back to the dataset total_gross
# group by year and compute the average inflation adjusted gross.

#total_gross['year'] = pd.DatetimeIndex(total_gross['release_date']).year
#total_gross=total_gross.assign(year = pd.DatetimeIndex(total_gross['release_date']).year)

direct_gross['inflation_adjusted_gross'] =direct_gross['inflation_adjusted_gross'].replace({'\$': '', ',': ''}, regex=True).astype(float)
avg_inflation_gross_by_director = pd.DataFrame(direct_gross.groupby('director')['inflation_adjusted_gross'].mean().sort_values(ascending=False)).sort_values(by='director', ascending=True)
avg_inflation_gross_by_director =avg_inflation_gross_by_director.reset_index()
avg_inflation_gross_by_director.head()
# Out:
#          director  inflation_adjusted_gross
# 0     Art Stevens              1.331189e+08
# 1      Barry Cook              2.168078e+08
# 2  Ben Sharpsteen              2.188229e+09
# 3    Byron Howard              3.412682e+08
# 4      Chris Buck              3.494487e+08

# %% [markdown]
# Now that we have it in the proper format, we can generate a bar plot to visualize it.

# %%
# Use altair to generate a bar plot
Average_gross_plot = (
    alt.Chart(avg_inflation_gross_by_director, width=500, height=300)
    .mark_bar()
    .encode(
        x=alt.X("director:O", title="Director"),
        y=alt.Y("inflation_adjusted_gross:Q", title="Average inflation Adjusted Gross"),
    )
    .properties(title="Average of Adjusted Gross by Year")
)
Average_gross_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# From the above plot we can see that David Hand has the highest average gross income (adjusted for inflation).

# %% [markdown]
# As a second visualization, lets take a look at the number of movies of each director.. To do this, I need to count the movies by each director

# %%
# extract rows with out NAN values in the 'parent_id' column using the drop.na() function
# themes_with_parents = themes[themes['parent_id'].notnull()]
movies_with_director = direct_gross.dropna(subset=["director"])
movies_with_director
# Out:
#                                 movie_title  release_date      genre  \
# 0           Snow White and the Seven Dwarfs  Dec 21, 1937    Musical
# 1                                 Pinocchio   Feb 9, 1940  Adventure
# 2                                  Fantasia  Nov 13, 1940    Musical
# 4                                Cinderella  Feb 15, 1950      Drama
# 6                        Lady and the Tramp  Jun 22, 1955      Drama
# 7                           Sleeping Beauty  Jan 29, 1959      Drama
# 8                            101 Dalmatians  Jan 25, 1961     Comedy
# 12                   The Sword in the Stone  Dec 25, 1963  Adventure
# 13                          The Jungle Book  Oct 18, 1967    Musical
# 15                           The Aristocats  Apr 24, 1970    Musical
# 20   The Many Adventures of Winnie the Pooh  Mar 11, 1977        NaN
# 21                             The Rescuers  Jun 22, 1977  Adventure
# 28                    The Fox and the Hound  Jul 10, 1981     Comedy
# 41                       The Black Cauldron  Jul 24, 1985  Adventure
# 48                The Great Mouse Detective   Jul 2, 1986  Adventure
# 72                         Oliver & Company  Nov 18, 1988  Adventure
# 83                       The Little Mermaid  Nov 15, 1989  Adventure
# 97                  The Rescuers Down Under  Nov 16, 1990  Adventure
# 114                    Beauty and the Beast  Nov 13, 1991    Musical
# 135                                 Aladdin  Nov 11, 1992     Comedy
# 179                           The Lion King  Jun 15, 1994  Adventure
# 194                         The Jungle Book  Dec 25, 1994  Adventure
# 210                              Pocahontas  Jun 10, 1995  Adventure
# 242             The Hunchback of Notre Dame  Jun 21, 1996  Adventure
# 252                          101 Dalmatians  Nov 27, 1996     Comedy
# 265                                Hercules  Jun 13, 1997  Adventure
# 285                                   Mulan  Jun 19, 1998  Adventure
# 306                                  Tarzan  Jun 16, 1999  Adventure
# 327                                Dinosaur  May 19, 2000  Adventure
# 338                The Emperor's New Groove  Dec 15, 2000  Adventure
# 344               Atlantis: The Lost Empire   Jun 8, 2001  Adventure
# 365                           Lilo & Stitch  Jun 21, 2002  Adventure
# 373                         Treasure Planet  Nov 27, 2002  Adventure
# 391                            Brother Bear  Oct 24, 2003  Adventure
# 400                       Home on the Range   Apr 2, 2004     Comedy
# 428                          Chicken Little   Nov 4, 2005  Adventure
# 453                      Meet the Robinsons  Mar 30, 2007  Adventure
# 475                                    Bolt  Nov 21, 2008     Comedy
# 491               The Princess and the Frog  Nov 25, 2009  Adventure
# 494                     Alice in Wonderland   Mar 5, 2010  Adventure
# 505                                 Tangled  Nov 24, 2010  Adventure
# 515                         Winnie the Pooh  Jul 15, 2011  Adventure
# 529                          Wreck-It Ralph   Nov 2, 2012  Adventure
# 539                                  Frozen  Nov 22, 2013  Adventure
# 552                              Big Hero 6   Nov 7, 2014  Adventure
# 556                              Cinderella  Mar 13, 2015      Drama
# 566                                Zootopia   Mar 4, 2016  Adventure
# 567                         The Jungle Book  Apr 15, 2016  Adventure
# 577                                   Moana  Nov 23, 2016  Adventure
#
#     MPAA_rating   total_gross  inflation_adjusted_gross  \
# 0             G  $184,925,485              5.228953e+09
# 1             G   $84,300,000              2.188229e+09
# 2             G   $83,320,000              2.187091e+09
# 4             G   $85,000,000              9.206087e+08
# 6             G   $93,600,000              1.236036e+09
# 7           NaN    $9,464,608              2.150583e+07
# 8             G  $153,000,000              1.362871e+09
# 12          NaN   $22,182,353              1.538708e+08
# 13    Not Rated  $141,843,000              7.896123e+08
# 15            G   $55,675,257              2.551615e+08
# 20          NaN            $0              0.000000e+00
# 21          NaN   $48,775,599              1.597439e+08
# 28          NaN   $43,899,231              1.331189e+08
# 41          NaN   $21,288,692              5.055314e+07
# 48          NaN   $23,605,534              5.363737e+07
# 72            G   $49,576,671              1.022545e+08
# 83            G  $111,543,479              2.237260e+08
# 97            G   $27,931,461              5.579673e+07
# 114           G  $218,951,625              3.630177e+08
# 135           G  $217,350,219              4.419692e+08
# 179           G  $422,780,140              7.616409e+08
# 194          PG   $44,342,956              8.893032e+07
# 210           G  $141,579,773              2.743710e+08
# 242           G  $100,138,851              1.909888e+08
# 252           G  $136,189,294              2.587289e+08
# 265           G   $99,112,101              1.820294e+08
# 285           G  $120,620,254              2.168078e+08
# 306           G  $171,091,819              2.839003e+08
# 327          PG  $137,748,063              2.154390e+08
# 338           G   $89,296,573              1.367893e+08
# 344          PG   $84,052,762              1.251881e+08
# 365          PG  $145,771,527              2.115067e+08
# 373          PG   $38,120,554              5.518914e+07
# 391           G   $85,336,277              1.192183e+08
# 400          PG   $50,026,353              6.791017e+07
# 428           G  $135,386,665              1.779547e+08
# 453           G   $97,822,171              1.198606e+08
# 475          PG  $114,053,759              1.337025e+08
# 491           G  $104,400,899              1.163165e+08
# 494          PG  $334,191,110              3.570635e+08
# 505          PG  $200,821,936              2.143885e+08
# 515           G   $26,692,846              2.837587e+07
# 529          PG  $189,412,677              2.003550e+08
# 539          PG  $400,738,009              4.149972e+08
# 552          PG  $222,527,828              2.292492e+08
# 556          PG  $201,151,353              2.011514e+08
# 566          PG  $341,268,248              3.412682e+08
# 567          PG  $364,001,123              3.640011e+08
# 577          PG  $246,082,029              2.460820e+08
#
#                                        name             director _merge
# 0           Snow White and the Seven Dwarfs           David Hand   both
# 1                                 Pinocchio       Ben Sharpsteen   both
# 2                                  Fantasia         full credits   both
# 4                                Cinderella      Wilfred Jackson   both
# 6                        Lady and the Tramp       Hamilton Luske   both
# 7                           Sleeping Beauty       Clyde Geronimi   both
# 8                            101 Dalmatians  Wolfgang Reitherman   both
# 12                   The Sword in the Stone  Wolfgang Reitherman   both
# 13                          The Jungle Book  Wolfgang Reitherman   both
# 15                           The Aristocats  Wolfgang Reitherman   both
# 20   The Many Adventures of Winnie the Pooh  Wolfgang Reitherman   both
# 21                             The Rescuers  Wolfgang Reitherman   both
# 28                    The Fox and the Hound          Art Stevens   both
# 41                       The Black Cauldron           Ted Berman   both
# 48                The Great Mouse Detective         Ron Clements   both
# 72                         Oliver & Company      George Scribner   both
# 83                       The Little Mermaid         Ron Clements   both
# 97                  The Rescuers Down Under         Mike Gabriel   both
# 114                    Beauty and the Beast       Gary Trousdale   both
# 135                                 Aladdin         Ron Clements   both
# 179                           The Lion King         Roger Allers   both
# 194                         The Jungle Book  Wolfgang Reitherman   both
# 210                              Pocahontas         Mike Gabriel   both
# 242             The Hunchback of Notre Dame       Gary Trousdale   both
# 252                          101 Dalmatians  Wolfgang Reitherman   both
# 265                                Hercules         Ron Clements   both
# 285                                   Mulan           Barry Cook   both
# 306                                  Tarzan           Chris Buck   both
# 327                                Dinosaur         Ralph Zondag   both
# 338                The Emperor's New Groove          Mark Dindal   both
# 344               Atlantis: The Lost Empire       Gary Trousdale   both
# 365                           Lilo & Stitch        Chris Sanders   both
# 373                         Treasure Planet         Ron Clements   both
# 391                            Brother Bear        Robert Walker   both
# 400                       Home on the Range            Will Finn   both
# 428                          Chicken Little          Mark Dindal   both
# 453                      Meet the Robinsons  Stephen J. Anderson   both
# 475                                    Bolt       Chris Williams   both
# 491               The Princess and the Frog         Ron Clements   both
# 494                     Alice in Wonderland       Clyde Geronimi   both
# 505                                 Tangled         Nathan Greno   both
# 515                         Winnie the Pooh  Stephen J. Anderson   both
# 529                          Wreck-It Ralph           Rich Moore   both
# 539                                  Frozen           Chris Buck   both
# 552                              Big Hero 6             Don Hall   both
# 556                              Cinderella      Wilfred Jackson   both
# 566                                Zootopia         Byron Howard   both
# 567                         The Jungle Book  Wolfgang Reitherman   both
# 577                                   Moana         Ron Clements   both

# %% [markdown]
# Now lets group by genre and count the number of movies. to do this, I will import and use the script I created with a count function that takes in a dataframe and groups it by a certian column and then applies a specified aggreating function.

# %%
# import the custom script
import script as scpt

# run it on the data
movie_count = scpt.count_movie(movies_with_director, 'director','movie_title' )
movie_count
# Out:
#                director  count
# 0           Art Stevens      1
# 1            Barry Cook      1
# 2        Ben Sharpsteen      1
# 3          Byron Howard      1
# 4            Chris Buck      2
# 5         Chris Sanders      1
# 6        Chris Williams      1
# 7        Clyde Geronimi      2
# 8            David Hand      1
# 9              Don Hall      1
# 10       Gary Trousdale      3
# 11      George Scribner      1
# 12       Hamilton Luske      1
# 13          Mark Dindal      2
# 14         Mike Gabriel      2
# 15         Nathan Greno      1
# 16         Ralph Zondag      1
# 17           Rich Moore      1
# 18        Robert Walker      1
# 19         Roger Allers      1
# 20         Ron Clements      7
# 21  Stephen J. Anderson      2
# 22           Ted Berman      1
# 23      Wilfred Jackson      2
# 24            Will Finn      1
# 25  Wolfgang Reitherman      9
# 26         full credits      1

# %% [markdown]
# lets do a scatter plot of the themes with the most parents.

# %%
# first sort the counts and extract the top 20
top_5_movies = movie_count.sort_values(by=["count"], ascending=False)[
    :5
]

# now plot it using altair
top_5_genre_plot = (
    alt.Chart(top_5_movies, width=500, height=300)
    .mark_circle()
    .encode(
        x=alt.X("director:O", sort="y", title="Genre/Type"),
        y=alt.Y("count:Q", title="Number of Movies"),
    )
    .properties(title="Top 5 director made movies")
)
top_5_genre_plot
# Out:
# alt.Chart(...)
